# %%
import pandas as pd
import numpy as np

import gzip
import os
import json
import re
import itertools

from IPython.display import Image, display
from IPython.core.display import HTML 
from tqdm import tqdm

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')


meta_path = './amazon/meta_Software.json.gz'
reviews_path = os.path.join('amazon', 'Software.json.gz')

# %% [markdown]
# ## Metadata
# <ul>
#     <li><tt>asin</tt> - ID of the product, e.g. <a href="http://www.amazon.com/dp/0000031852">0000031852</a></li>
#     <li><tt>title</tt> - name of the product</li>
#     <li><tt>feature</tt> - bullet-point format features of the product</li>
#     <li><tt>description</tt> - description of the product</li>
#     <li><tt>price</tt> - price in US dollars (at time of crawl)</li>
#     <li><tt>image</tt> - url of the product image</li>
#     <li><tt>related</tt> - related products (also bought, also viewed, bought together, buy after viewing)</li>
#     <li><tt>salesRank</tt> - sales rank information</li>
#     <li><tt>brand</tt> - brand name</li>
#     <li><tt>categories</tt> - list of categories the product belongs to</li>
#     <li><tt>tech1</tt> - the first technical detail table of the product</li>
#     <li><tt>tech2</tt> - the second technical detail table of the product</li>
#     <li><tt>similar</tt> - similar product table</li>
#   </ul>

# %%
# %time df_meta = getDF(meta_path)
df_meta.head()
# Out:
# CPU times: user 1.54 s, sys: 67.1 ms, total: 1.61 s
# Wall time: 1.71 s
#   category tech1                                        description fit  \
# 0       []                                                       []
# 1       []        [, <b>Latin rhythms that will get your kids si...
# 2       []        [<b>Connect is the only integrated learning sy...
# 3       []                                                       []
# 4       []        [<i>Anatomy &amp; Physiology Revealed Cat</i> ...
#
#                                                title  \
# 0  HOLT PHYSICS LESSON PRESENTATION CD-ROM QUICK ...
# 1  Sing, Watch, &amp; Learn Spanish (DVD + Guide)...
# 2  Connect with LearnSmart Access Card for Microb...
# 3  LearnSmart Standalone Access Card for Prescott...
# 4  Anatomy &amp; Physiology Revealed Student Acce...
#
#                                also_buy  \
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4  [0323394612, 0323227937, 1118527488]
#
#                                                image tech2  \
# 0                                                 []
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                   brand feature                  rank  \
# 0            HOLT. RINEHART AND WINSTON      []  25,550 in Software (
# 1                           McGraw Hill      []  15,792 in Software (
# 2  McGraw-Hill Science/Engineering/Math      []  16,900 in Software (
# 3                 McGraw-Hill Education      []  12,986 in Software (
# 4                 McGraw-Hill Education      []  14,861 in Software (
#
#   also_view  main_cat similar_item    date  \
# 0        []  Software               </div>
# 1        []  Software               </div>
# 2        []  Software               </div>
# 3        []  Software               </div>
# 4        []  Software               </div>
#
#                                                price        asin details
# 0  .a-box-inner{background-color:#fff}#alohaBuyBo...  0030672120     NaN
# 1                                                     0071480935     NaN
# 2                                                     007329506X     NaN
# 3                                                     0073513458     NaN
# 4                                              $4.83  0073525758     NaN

# %% [markdown]
# ## Reviews
#
# <ul>
#     <li><tt>reviewerID</tt> - ID of the reviewer, e.g. <a href="http://www.amazon.com/gp/cdp/member-reviews/A2SUAM1J3GNN3B">A2SUAM1J3GNN3B</a></li>
#     <li><tt>asin</tt> - ID of the product, e.g. <a href="http://www.amazon.com/dp/0000013714">0000013714</a></li>
#     <li><tt>reviewerName</tt> - name of the reviewer</li>
#     <li><tt>vote</tt> - helpful votes of the review</li>
#     <li><tt>style</tt> - a disctionary of the product metadata, e.g., "Format" is "Hardcover"</li>
#     <li><tt>reviewText</tt> - text of the review</li>
#     <li><tt>overall</tt> - rating of the product</li>
#     <li><tt>summary</tt> - summary of the review</li>
#     <li><tt>unixReviewTime</tt> - time of the review (unix time)</li>
#     <li><tt>reviewTime</tt> - time of the review (raw)</li>
#     <li><tt>image</tt> - images that users post after they have received the product</li>
#   </ul>

# %%
# %time df_review = getDF(reviews_path)
df_review.head()
# Out:
# CPU times: user 11.3 s, sys: 490 ms, total: 11.8 s
# Wall time: 12.3 s
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      4.0      True  03 11, 2014  A240ORQ2LF9LUI  0077613252
# 1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE  0077613252
# 2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J  0077613252
# 3      3.0      True  02 17, 2014   APRDVZ6QBIQXT  0077613252
# 4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV  0077775473
#
#                         style         reviewerName  \
# 0  {'Format:': ' Loose Leaf'}           Michelle W
# 1  {'Format:': ' Loose Leaf'}  Rosalind White Ames
# 2  {'Format:': ' Loose Leaf'}       Allan R. Baker
# 3  {'Format:': ' Loose Leaf'}                 Lucy
# 4                         NaN            Albert V.
#
#                                           reviewText  \
# 0  The materials arrived early and were in excell...
# 1  I am really enjoying this book with the worksh...
# 2  IF YOU ARE TAKING THIS CLASS DON"T WASTE YOUR ...
# 3  This book was missing pages!!! Important pages...
# 4  I have used LearnSmart and can officially say ...
#
#                          summary  unixReviewTime vote image
# 0                 Material Great      1394496000  NaN   NaN
# 1                         Health      1393113600  NaN   NaN
# 2             ARE YOU KIDING ME?      1392595200    7   NaN
# 3                missing pages!!      1392595200    3   NaN
# 4  Best study product out there!      1381708800  NaN   NaN

# %%
imgs = df_meta[pd.notnull(df_meta.image)].image
for i in range(1, 6):
    display(Image(url=imgs.iloc[i][0], width=200, height=200))
# Out:
# <img src="https://images-na.ssl-images-amazon.com/images/I/51BtLn2-L-L._SX38_SY50_CR,0,0,38,50_.jpg" width="200" height="200"/>
# <img src="https://images-na.ssl-images-amazon.com/images/I/51z1MKLSD3L._SX38_SY50_CR,0,0,38,50_.jpg" width="200" height="200"/>
# <img src="https://images-na.ssl-images-amazon.com/images/I/519Oje-rEhL._SX38_SY50_CR,0,0,38,50_.jpg" width="200" height="200"/>
# <img src="https://images-na.ssl-images-amazon.com/images/I/51Do0BbcTkL._SX38_SY50_CR,0,0,38,50_.jpg" width="200" height="200"/>
# <img src="https://images-na.ssl-images-amazon.com/images/I/51sAaOLFUCL._SX38_SY50_CR,0,0,38,50_.jpg" width="200" height="200"/>

# %%
imgs[1]
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/51BtLn2-L-L._SX38_SY50_CR,0,0,38,50_.jpg']

# %% [markdown]
# ## Remover valores repetidos

# %%
df_review.drop_duplicates(subset=['reviewerID', 'asin'], inplace=True)
df_meta.drop_duplicates(subset=['asin'], inplace=True)

# %% [markdown]
# ## Limpieza de datos
# Para la columna price, para toda celda donde podramos encontrar el precio unicamente se deja este, si hay texto basura o no hay nada este se remplazara por la media de los precios encontrados.

# %%
def df_stay_with_cols(df, cols: set):
    cols = set(df.columns.values) - cols
    return df.drop(list(cols), axis=1)


df_meta = df_stay_with_cols(df_meta, {'asin', 'title', 'brand', 'price'})
df_review = df_stay_with_cols(df_review, {'overall', 'reviewerID', 'asin', 'reviewerName', 'unixReviewTime'})
display(df_meta.head())
display(df_review.head())
# Out:
#                                                title  \
# 0  HOLT PHYSICS LESSON PRESENTATION CD-ROM QUICK ...
# 1  Sing, Watch, &amp; Learn Spanish (DVD + Guide)...
# 2  Connect with LearnSmart Access Card for Microb...
# 3  LearnSmart Standalone Access Card for Prescott...
# 4  Anatomy &amp; Physiology Revealed Student Acce...
#
#                                   brand  \
# 0            HOLT. RINEHART AND WINSTON
# 1                           McGraw Hill
# 2  McGraw-Hill Science/Engineering/Math
# 3                 McGraw-Hill Education
# 4                 McGraw-Hill Education
#
#                                                price        asin
# 0  .a-box-inner{background-color:#fff}#alohaBuyBo...  0030672120
# 1                                                     0071480935
# 2                                                     007329506X
# 3                                                     0073513458
# 4                                              $4.83  0073525758
#    overall      reviewerID        asin         reviewerName  unixReviewTime
# 0      4.0  A240ORQ2LF9LUI  0077613252           Michelle W      1394496000
# 1      4.0  A1YCCU0YRLS0FE  0077613252  Rosalind White Ames      1393113600
# 2      1.0  A1BJHRQDYVAY2J  0077613252       Allan R. Baker      1392595200
# 3      3.0   APRDVZ6QBIQXT  0077613252                 Lucy      1392595200
# 4      5.0  A2JZTTBSLS1QXV  0077775473            Albert V.      1381708800

# %%
def get_price_or_empty_string(s):
    groups = re_dollar.search(s)
    if groups:
        return groups.group(0).replace(',', '')  # remove ',' since we'll apply float function
    return ''

def impute_sign(df, col):
    idx = df['price'].apply(lambda x: len(x) != 0)  # select non-empty cells
    re_dollar = re.compile('[\d]+[,\d\d\d]*[\.[\d]*]?')  # compile regex for matching price like 443,432.00
    serie = df.loc[idx, col].apply(get_price_or_empty_string)  # clean cells with weird text
    df.loc[idx, col] = serie  # now text will be replaced by ''
    mu = serie.apply(lambda x: float(x) if len(x) > 0 else 0).mean()  
    idx = df[col].apply(lambda x: len(x) == 0)  # df.price == ''  # works as well
    df.loc[idx, col] = mu  # replace empty values by mu
    df[col] = df[col].apply(np.float,)  # change dtype


impute_sign(df_meta, 'price')
df_meta.head()  # do we need a price conversion ?
# Out:
#                                                title  \
# 0  HOLT PHYSICS LESSON PRESENTATION CD-ROM QUICK ...
# 1  Sing, Watch, &amp; Learn Spanish (DVD + Guide)...
# 2  Connect with LearnSmart Access Card for Microb...
# 3  LearnSmart Standalone Access Card for Prescott...
# 4  Anatomy &amp; Physiology Revealed Student Acce...
#
#                                   brand      price        asin
# 0            HOLT. RINEHART AND WINSTON   3.000000  0030672120
# 1                           McGraw Hill  44.962987  0071480935
# 2  McGraw-Hill Science/Engineering/Math  44.962987  007329506X
# 3                 McGraw-Hill Education  44.962987  0073513458
# 4                 McGraw-Hill Education   4.830000  0073525758

# %% [markdown]
# Nos quedamos con aquellos productos que hayan sido valorados al menos n veces.

# %%
def filter_by_freq(df: pd.DataFrame, column: str, min_freq: int) -> pd.DataFrame:
    """Filters the DataFrame based on the value frequency in the specified column.

    :param df: DataFrame to be filtered.
    :param column: Column name that should be frequency filtered.
    :param min_freq: Minimal value frequency for the row to be accepted.
    :return: Filter serie.
    """
    freq = df[column].value_counts()  # Frequencies of each value in the column.
    frequent_values = freq[freq >= min_freq].index  # Select frequent values. Value is in the index.
    return df[column].isin(frequent_values)  # return series filter

def label_df(df, ):  # not used
    le_user = preprocessing.LabelEncoder().fit(df_dense['user'])
    le_item = preprocessing.LabelEncoder().fit(df_dense['item'])
    df.loc[:, 'user'] = le_user.transform(df_dense['user'])
    df.loc[:, 'item'] = le_item.transform(df_dense['item'])

# %%
filter_user = filter_by_freq(df_review, 'reviewerID', 5)
filter_item = filter_by_freq(df_review, 'asin', 5)
df_review_dense = df_review[filter_user & filter_item]

print('shape')
print('df original: ', df_review.shape, 'df_dense: ', df_review_dense.shape)
df_review_dense.head()
# Out:
# shape
# df original:  (450578, 5) df_dense:  (21894, 5)
#     overall      reviewerID        asin  reviewerName  unixReviewTime
# 21      4.0  A38NELQT98S4H8  0321719816     WB Halper      1287532800
# 22      4.0  A3QJU4FEN8PQSZ  0321719816        Grimmy      1287360000
# 23      5.0   ACJT8MUC0LRF0  0321719816     D. Fowler      1287187200
# 25      5.0   AYUF7YETYOLNX  0321719816  Bryan Newman      1286841600
# 26      5.0  A31ICLWQ9CSHRS  0321719816    Al Swanson      1286409600

# %%
def extract_rows_from_dense(df_src, df_sel, col):
    return df_src[df_src[col].isin(df_sel[col])]


df_meta_db = extract_rows_from_dense(df_meta, df_review_dense, 'asin')
df_review_db = extract_rows_from_dense(df_review, df_review_dense, 'reviewerID')
df_review_name = df_review_db.drop_duplicates(subset=['reviewerID']).copy()

# %% [markdown]
# ### Observacion
# Hay inconsistencias en los archivos, pues en el meta no hay info de algunos elementos valorados. Se eliminaran estas valoraciones.

# %%
sum(~df_review_db.asin.isin(df_meta_db.asin))
# Out:
# 1604

# %%
print(df_review_db.shape)
df_review_db = extract_rows_from_dense(df_review_db, df_meta_db, 'asin')
# Out:
# (23491, 5)

# %%
df_review_db.shape
# Out:
# (21887, 5)

# %% [markdown]
# ## Carga de datos csv a la base de datos

# %%
"""
ALTER TABLE producto MODIFY idProducto VARCHAR(20);
ALTER TABLE producto MODIFY nombre VARCHAR(400);
ALTER TABLE producto MODIFY marca VARCHAR(100);

show create table sociomembresia ;
ALTER TABLE sociomembresia DROP FOREIGN KEY sociomembresia_ibfk_1;
ALTER TABLE socio modify idSocio VARCHAR(40);
ALTER TABLE sociomembresia modify idSocio VARCHAR(40);
ALTER TABLE sociomembresia 
    ADD CONSTRAINT sociomembresia_ibfk_1 
    FOREIGN KEY (idSocio) REFERENCES socio (idSocio) ON DELETE CASCADE ON UPDATE CASCADE;


alter table socio modify idSocio VARCHAR(40);
ALTER TABLE socio MODIFY nombre VARCHAR(120);

DROP TABLE IF EXISTS valoracion;
CREATE TABLE valoracion (
    idSocio VARCHAR(40) COLLATE latin1_swedish_ci NOT NULL,
    idProducto VARCHAR(20) COLLATE latin1_swedish_ci NOT NULL,
    rating DOUBLE,
    unix_time VARCHAR(20),
    PRIMARY KEY(idSocio, idProducto)
);

ALTER TABLE valoracion 
    ADD CONSTRAINT valoracion_socio
    FOREIGN KEY (idSocio) REFERENCES socio(idSocio) 
        ON DELETE CASCADE ON UPDATE CASCADE;
    
ALTER TABLE valoracion 
    ADD CONSTRAINT valoracion_producto
    FOREIGN KEY (idProducto) REFERENCES producto(idProducto) 
        ON DELETE CASCADE ON UPDATE CASCADE;   
"""
# Out:
# '\nalter table producto modify idProducto VARCHAR(20);\nalter table producto modify nombre VARCHAR(400);\nalter table producto modify marca VARCHAR(100);\n\nshow create table sociomembresia ;\nALTER TABLE sociomembresia DROP FOREIGN KEY sociomembresia_ibfk_1;\nALTER TABLE socio modify idSocio VARCHAR(40);\nALTER TABLE sociomembresia modify idSocio VARCHAR(40);\nALTER TABLE sociomembresia \n    ADD CONSTRAINT sociomembresia_ibfk_1 \n    FOREIGN KEY (idSocio) REFERENCES socio (idSocio) ON DELETE CASCADE ON UPDATE CASCADE;\n\n\nalter table socio modify idSocio VARCHAR(40);\nALTER TABLE socio MODIFY nombre VARCHAR(120);\n\nDROP TABLE IF EXISTS valoracion;\nCREATE TABLE valoracion (\n    idSocio VARCHAR(40) COLLATE latin1_swedish_ci NOT NULL,\n    idProducto VARCHAR(20) COLLATE latin1_swedish_ci NOT NULL,\n    rating DOUBLE,\n    unix_time VARCHAR(20),\n    PRIMARY KEY(idSocio, idProducto)\n);\n\nALTER TABLE valoracion \n    ADD CONSTRAINT valoracion_socio\n    FOREIGN KEY (idSocio) REFERENCES socio(idSocio) \n        ON DELETE CASCADE ON UPDATE CASCADE;\n    \nALTER TABLE valoracion \n    ADD CONSTRAINT valoracion_producto\n    FOREIGN KEY (idProducto) REFERENCES producto(idProducto) \n        ON DELETE CASCADE ON UPDATE CASCADE;   \n'

# %%
# !pip3 install flask flask-mysql
# Out:
# Requirement already satisfied: flask in /home/aingeru/anaconda3/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: flask-mysql in /home/aingeru/anaconda3/lib/python3.7/site-packages (1.5.1)
# Requirement already satisfied: Werkzeug>=0.15 in /home/aingeru/anaconda3/lib/python3.7/site-packages (from flask) (1.0.0)
# Requirement already satisfied: click>=5.1 in /home/aingeru/anaconda3/lib/python3.7/site-packages (from flask) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/aingeru/anaconda3/lib/python3.7/site-packages (from flask) (2.11.1)
# Requirement already satisfied: itsdangerous>=0.24 in /home/aingeru/anaconda3/lib/python3.7/site-packages (from flask) (1.1.0)
# Requirement already satisfied: PyMySQL in /home/aingeru/anaconda3/lib/python3.7/site-packages (from flask-mysql) (0.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/aingeru/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask) (1.1.1)
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/aingeru/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from flask import Flask, render_template, request, jsonify
from flaskext.mysql import MySQL
from db_helper import DbHelper

# %%
app = Flask(__name__)
app.config.from_pyfile('config.py')

mysql = MySQL()
mysql.init_app(app)

conn = mysql.connect()
cursor = conn.cursor()

db = DbHelper(conn, cursor)

# %% [markdown]
# ## Insercion en producto

# %%
query = f'''INSERT INTO producto(idProducto, nombre, marca, precioUnitario, idSubCat) 
        VALUES '''
n = df_meta_db.shape[0]
conn.begin()
for i, row in tqdm(df_meta_db.iterrows(), total=n):
    val = f""" ("{row['asin']}", "{row['title'].replace('"', '""')}", "{row['brand']}", {row['price']}, 17); """
    cursor.execute(query + val)

        
print(query + val)
# Out:
#   0%|          | 0/4494 [00:00<?, ?it/s]
#   0%|          | 1/4494 [00:01<1:41:23,  1.35s/it]
#   0%|          | 2/4494 [00:01<1:14:49,  1.00it/s]
#   0%|          | 7/4494 [00:01<52:53,  1.41it/s]
#   1%|          | 28/4494 [00:01<37:06,  2.01it/s]
#   1%|          | 38/4494 [00:02<26:34,  2.80it/s]
#   2%|▏         | 104/4494 [00:02<18:22,  3.98it/s]
#   3%|▎         | 120/4494 [00:02<13:31,  5.39it/s]
#   6%|▌         | 277/4494 [00:03<09:09,  7.68it/s]
#   8%|▊         | 380/4494 [00:03<06:16, 10.93it/s]
#  10%|▉         | 434/4494 [00:03<04:22, 15.48it/s]
#  11%|█         | 485/4494 [00:04<03:19, 20.08it/s]
#  13%|█▎        | 594/4494 [00:04<02:18, 28.23it/s]
#  14%|█▍        | 637/4494 [00:04<01:42, 37.74it/s]
#  17%|█▋        | 746/4494 [00:04<01:10, 52.94it/s]
#  20%|█▉        | 893/4494 [00:04<00:48, 74.29it/s]
#  22%|██▏       | 967/4494 [00:04<00:36, 95.76it/s]
#  23%|██▎       | 1027/4494 [00:05<00:28, 121.10it/s]
#  24%|██▍       | 1083/4494 [00:05<00:22, 149.64it/s]
#  27%|██▋       | 1197/4494 [00:05<00:16, 196.64it/s]
#  28%|██▊       | 1252/4494 [00:07<00:40, 80.82it/s]
#  30%|███       | 1360/4494 [00:07<00:28, 111.86it/s]
#  32%|███▏      | 1420/4494 [00:07<00:27, 111.11it/s]
#  34%|███▍      | 1532/4494 [00:07<00:19, 152.22it/s]
#  36%|███▌      | 1597/4494 [00:08<00:15, 187.25it/s]
#  38%|███▊      | 1702/4494 [00:08<00:11, 234.49it/s]
#  41%|████▏     | 1860/4494 [00:08<00:09, 284.40it/s]
#  44%|████▍     | 1977/4494 [00:08<00:07, 318.59it/s]
#  45%|████▌     | 2031/4494 [00:08<00:07, 319.95it/s]
#  47%|████▋     | 2106/4494 [00:09<00:06, 386.14it/s]
#  48%|████▊     | 2167/4494 [00:09<00:06, 355.06it/s]
#  49%|████▉     | 2215/4494 [00:09<00:05, 384.91it/s]
#  50%|█████     | 2263/4494 [00:09<00:05, 379.43it/s]
#  52%|█████▏    | 2323/4494 [00:09<00:06, 352.72it/s]
#  53%|█████▎    | 2364/4494 [00:09<00:05, 361.44it/s]
#  55%|█████▍    | 2469/4494 [00:09<00:04, 408.58it/s]
#  57%|█████▋    | 2580/4494 [00:10<00:03, 480.75it/s]
#  59%|█████▊    | 2637/4494 [00:10<00:04, 418.69it/s]
#  61%|██████    | 2732/4494 [00:10<00:04, 362.10it/s]
#  62%|██████▏   | 2775/4494 [00:10<00:06, 272.56it/s]
#  65%|██████▍   | 2903/4494 [00:11<00:05, 310.20it/s]
#  65%|██████▌   | 2942/4494 [00:11<00:06, 236.19it/s]
#  68%|██████▊   | 3058/4494 [00:11<00:04, 296.29it/s]
#  69%|██████▉   | 3110/4494 [00:11<00:04, 286.01it/s]
#  70%|███████   | 3149/4494 [00:11<00:04, 298.09it/s]
#  71%|███████   | 3193/4494 [00:11<00:03, 328.96it/s]
#  72%|███████▏  | 3232/4494 [00:12<00:04, 284.81it/s]
#  73%|███████▎  | 3291/4494 [00:12<00:03, 336.82it/s]
#  75%|███████▍  | 3349/4494 [00:12<00:03, 294.93it/s]
#  77%|███████▋  | 3447/4494 [00:12<00:02, 373.15it/s]
#  78%|███████▊  | 3502/4494 [00:12<00:02, 351.32it/s]
#  80%|████████  | 3601/4494 [00:12<00:02, 432.32it/s]
#  82%|████████▏ | 3663/4494 [00:13<00:03, 236.63it/s]
#  84%|████████▍ | 3771/4494 [00:13<00:02, 298.41it/s]
#  85%|████████▌ | 3827/4494 [00:14<00:05, 111.67it/s]
#  88%|████████▊ | 3971/4494 [00:14<00:03, 154.40it/s]
#  91%|█████████ | 4071/4494 [00:15<00:02, 199.76it/s]
#  92%|█████████▏| 4140/4494 [00:15<00:01, 238.04it/s]
#  95%|█████████▍| 4247/4494 [00:15<00:00, 310.03it/s]
#  97%|█████████▋| 4355/4494 [00:15<00:00, 383.73it/s]
# 100%|██████████| 4494/4494 [00:15<00:00, 284.62it/s]
# INSERT INTO producto(idProducto, nombre, marca, precioUnitario, idSubCat)
#         VALUES  ("B01HAP3NJM", "CorelDRAW Home &amp; Student Suite X8 for PC (Old Version)", "Corel", 67.48, 17);

# %%
# conn.rollback()
conn.commit()

# %%
df_review_db.head()
# Out:
#     overall      reviewerID        asin  reviewerName  unixReviewTime
# 21      4.0  A38NELQT98S4H8  0321719816     WB Halper      1287532800
# 22      4.0  A3QJU4FEN8PQSZ  0321719816        Grimmy      1287360000
# 23      5.0   ACJT8MUC0LRF0  0321719816     D. Fowler      1287187200
# 25      5.0   AYUF7YETYOLNX  0321719816  Bryan Newman      1286841600
# 26      5.0  A31ICLWQ9CSHRS  0321719816    Al Swanson      1286409600

# %%
df_review_db.reviewerID.value_counts()
# Out:
# A5JLAU2ARJ0BO     72
# A680RUE1FDO8B     67
# A3W4D8XOGLWUN5    66
# A225G2TFM76GYX    66
# A15S4XW3CRISZ5    64
#                   ..
# A1SRMG16HF5TLD     5
# A2T4T4U20V7HSO     5
# A2U80U8KAR1DL      5
# A1FW6NVKN9B9VH     5
# A10M0GF5ZFODYU     5
# Name: reviewerID, Length: 3176, dtype: int64

# %%
df_review_db.reviewerID.apply(len).max()
# Out:
# 20

# %%
df_review_db.reviewerName.map(str).apply(len).max()  # there's a float over there...
# Out:
# 66

# %%
df_review_name.unixReviewTime.map(str).map(len).max()
# Out:
# 10

# %% [markdown]
# ## Insercion en socio

# %%
query = f'''INSERT INTO socio(idSocio, nombre) 
        VALUES '''
n = df_review_name.shape[0]
conn.begin()
for i, row in tqdm(df_review_name.iterrows(), total=n):
    val = f""" ("{row['reviewerID']}", "{str(row['reviewerName']).replace('"', '""')}"); """
    cursor.execute(query + val)
        
print(query + val)
# Out:
#   0%|          | 0/3176 [00:00<?, ?it/s]
#   1%|▏         | 46/3176 [00:00<00:09, 319.97it/s]
#   5%|▌         | 162/3176 [00:00<00:07, 399.07it/s]
#   6%|▌         | 198/3176 [00:00<00:19, 150.73it/s]
#  11%|█▏        | 363/3176 [00:01<00:13, 203.60it/s]
#  14%|█▍        | 441/3176 [00:01<00:11, 247.72it/s]
#  16%|█▌        | 495/3176 [00:01<00:10, 250.24it/s]
#  17%|█▋        | 539/3176 [00:01<00:09, 284.97it/s]
#  19%|█▊        | 593/3176 [00:01<00:07, 331.42it/s]
#  20%|██        | 650/3176 [00:01<00:10, 235.18it/s]
#  24%|██▎       | 747/3176 [00:02<00:08, 297.60it/s]
#  28%|██▊       | 905/3176 [00:02<00:05, 393.12it/s]
#  31%|███       | 987/3176 [00:02<00:06, 344.91it/s]
#  33%|███▎      | 1061/3176 [00:02<00:06, 312.53it/s]
#  38%|███▊      | 1196/3176 [00:02<00:04, 399.52it/s]
#  43%|████▎     | 1366/3176 [00:03<00:03, 518.27it/s]
#  46%|████▌     | 1467/3176 [00:03<00:04, 426.30it/s]
#  49%|████▊     | 1547/3176 [00:03<00:04, 403.43it/s]
#  53%|█████▎    | 1676/3176 [00:03<00:03, 437.76it/s]
#  55%|█████▍    | 1743/3176 [00:03<00:03, 415.30it/s]
#  59%|█████▉    | 1873/3176 [00:04<00:02, 517.20it/s]
#  61%|██████▏   | 1948/3176 [00:04<00:02, 562.98it/s]
#  64%|██████▎   | 2022/3176 [00:04<00:02, 511.36it/s]
#  67%|██████▋   | 2131/3176 [00:04<00:02, 521.49it/s]
#  69%|██████▉   | 2193/3176 [00:04<00:02, 351.61it/s]
#  74%|███████▍  | 2351/3176 [00:04<00:01, 458.51it/s]
#  79%|███████▉  | 2510/3176 [00:05<00:01, 561.37it/s]
#  82%|████████▏ | 2603/3176 [00:05<00:01, 463.41it/s]
#  85%|████████▌ | 2713/3176 [00:05<00:00, 528.10it/s]
#  88%|████████▊ | 2789/3176 [00:05<00:00, 429.10it/s]
#  91%|█████████ | 2894/3176 [00:05<00:00, 521.61it/s]
# 100%|██████████| 3176/3176 [00:06<00:00, 512.39it/s]
# INSERT INTO socio(idSocio, nombre)
#         VALUES  ("A30W19MJFRJE3J", "Tahoe Johnny");

# %%
#conn.rollback()
conn.commit()

# %%
query = f'''INSERT INTO valoracion(idSocio, idProducto, rating, unix_time) 
        VALUES '''
n = df_review_db.shape[0]
conn.begin()
for i, row in tqdm(df_review_db.iterrows(), total=n):
    val = f""" ("{row['reviewerID']}", "{row['asin']}", {row['overall']}, {row['unixReviewTime']} ); """
#     print(query + val)
    cursor.execute(query + val)
# Out:
#   0%|          | 0/21887 [00:00<?, ?it/s]
#
#   0%|          | 1/21887 [00:00<48:12,  7.57it/s]
#
#   0%|          | 65/21887 [00:00<33:49, 10.75it/s]
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A38NELQT98S4H8", "0321719816", 4.0, 1287532800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3QJU4FEN8PQSZ", "0321719816", 4.0, 1287360000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ACJT8MUC0LRF0", "0321719816", 5.0, 1287187200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AYUF7YETYOLNX", "0321719816", 5.0, 1286841600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A31ICLWQ9CSHRS", "0321719816", 5.0, 1286409600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2BVNVJOFXGZUB", "0321719816", 5.0, 1285459200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2JMJVNTBL7K7E", "0321719816", 5.0, 1302134400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A14JBDSWKPKTZA", "0321719816", 5.0, 1294444800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WCFDOCS73PNB", "0321719816", 5.0, 1288224000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A14638TGYH7GD9", "0321719816", 5.0, 1288224000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2VWE5SGNDS8HW", "0321719816", 3.0, 1287619200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A9ELHLPXF7JKD", "0321700945", 5.0, 1287273600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A13700AF4X40YG", "0321700945", 5.0, 1286928000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A23E9QQHJLNGUI", "0321700945", 5.0, 1286409600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3T7V207KRDE2O", "0321700945", 5.0, 1285545600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1GQRGB8FGSLIZ", "0321700945", 5.0, 1305417600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1E50L7PCVXLN4", "0321700945", 3.0, 1294531200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A10Y058K7B96C6", "0321700945", 5.0, 1291593600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3V7D0LH8L7BG0", "0321700945", 5.0, 1289779200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGVWTYW0ULXHT", "0321719824", 4.0, 1290816000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3QJU4FEN8PQSZ", "0321719824", 4.0, 1287619200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A31N0XY2UTB25C", "0321719824", 4.0, 1286668800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2BLFCOPSMBOZ9", "0321719824", 4.0, 1296259200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1S5G0CL6NZHM8", "0615179088", 4.0, 1397174400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2V5M5EJPOD2IU", "0615179088", 5.0, 1300838400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A306D2RZWTNZ5I", "0615179088", 5.0, 1253577600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A24X9HGDWV2ZZH", "0763855553", 1.0, 1512518400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AHEZP9ACDYJII", "0763855553", 5.0, 1498176000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WUYJJ7NPQ5H4", "0763855553", 1.0, 1490918400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AEBC5HHLPWMLC", "0763855553", 5.0, 1487203200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A340ECSASO3LQV", "0763855553", 1.0, 1485475200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AXGLPF6X39874", "0763855553", 5.0, 1464566400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AJK49DENMS2BT", "0763855553", 5.0, 1461801600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3UI63EESKUYHU", "0763855553", 5.0, 1460246400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2W22F71SEOLYK", "0763855553", 4.0, 1451001600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AK8GQ08WTHW4G", "0763855553", 5.0, 1450051200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AE16WAPPF7GUA", "0763855553", 5.0, 1446854400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MRPX3RM48T2I", "0763855553", 4.0, 1446076800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A318IDAWJ9ZYAY", "0763855553", 5.0, 1445990400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A17RBY97FPNKO7", "0763855553", 4.0, 1445299200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3NAKHGAT8QSJB", "0763855553", 1.0, 1442275200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ANGGNFE8DXGYC", "0763855553", 4.0, 1440892800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AAG3NRUUHI9C7", "0763855553", 5.0, 1438905600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2N4QZL8L2NVKX", "0763855553", 5.0, 1433289600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1EMDSTJDUE6B0", "0763855553", 3.0, 1430611200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A6M01NDCD957E", "0763855553", 5.0, 1429660800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3PAUB3M715CJC", "0763855553", 5.0, 1427155200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AEC7B85GKPM0W", "0763855553", 1.0, 1417478400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2MV80H0EYK38N", "0763855553", 4.0, 1417392000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A27QJQM1A0O8S6", "0763855553", 5.0, 1416268800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A29BGBRZPMLPZM", "0763855553", 2.0, 1414108800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3K6VZ6XT8PZAU", "0763855553", 5.0, 1401494400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A374KGFYENBQX4", "0763855553", 5.0, 1400630400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A22S7D0LP8GRDH", "0763855553", 5.0, 1397692800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A770EP3KUHKM", "0763855553", 5.0, 1396483200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3VV6SV0Z2HNTA", "0763855553", 5.0, 1396310400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2MKY8OUI8GZG1", "0763855553", 1.0, 1395014400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3VONQL7YW8UPM", "0763855553", 5.0, 1393804800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3N7T0DY83Y4IG", "0763855553", 4.0, 1388448000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AA90W95STFGAC", "0763855553", 4.0, 1381968000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AHNHLGKIZ2N3B", "0763855553", 3.0, 1381968000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A16QODENBJVUI1", "0763855553", 5.0, 1381881600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A376OJHLE6SU9Q", "0763855553", 4.0, 1381622400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1E5WXNTI7EO2A", "0763855553", 4.0, 1381190400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AEJAGHLC675A7", "0763855553", 4.0, 1380499200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A17A1KTVI3DG6U", "0763855553", 5.0, 1380412800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZZ5ASC403N74", "0763855553", 5.0, 1380412800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A4U27URFECK1U", "0763855553", 3.0, 1380240000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2CZ98V784SRJ0", "0763855553", 4.0, 1380153600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2GP6XJ1V3MM3L", "0763855553", 3.0, 1380153600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGOH8N902URMW", "0763855553", 5.0, 1380067200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3OIMUR42XIOFQ", "0763855553", 4.0, 1379721600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A379DLIAF0MFM5", "0763855553", 5.0, 1379635200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1GQRGB8FGSLIZ", "0763855553", 3.0, 1379462400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A12GIOKE26ZFKJ", "0976963027", 3.0, 1398902400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ACJT8MUC0LRF0", "0982697813", 5.0, 1306886400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A17BUUBOU0598B", "0982697813", 4.0, 1306800000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2EWTWUJYREJFO", "0982697813", 5.0, 1363305600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3963R7EPE3A7E", "0982697813", 5.0, 1326931200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZYJE40XW6MFG", "0982697813", 5.0, 1317168000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3TPNC3TKGCCEI", "0982697813", 4.0, 1314230400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3G007LQX6KGOD", "0982697813", 5.0, 1311120000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3BNMHRW2R35LK", "0982697813", 5.0, 1310601600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PI8VBCXXSGC7", "0982697813", 4.0, 1310169600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1D7VWS3DWS7X8", "0982697813", 5.0, 1309305600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1U6XG3OMP5S62", "1413313701", 4.0, 1290124800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATZJNEXX7LWD3", "1413313701", 4.0, 1289779200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A21U4DR8M6I9QN", "1413313701", 5.0, 1289347200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2BMSLF6UPAQOE", "1413313701", 5.0, 1416268800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2P6QCZWW3H1X6", "1413313701", 2.0, 1378857600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2AMTEB5UZEOXE", "1413313701", 5.0, 1353196800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3PJZ8TU8FDQ1K", "1413313701", 4.0, 1337817600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2ZJMLZ1IA2YA9", "1413313701", 5.0, 1334707200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A14JBDSWKPKTZA", "1413313701", 5.0, 1327708800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2L6QS8SVHT9RG", "1413313701", 4.0, 1317945600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A38DSYHNBYZNUG", "1413313701", 5.0, 1314835200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3R1WFO4KIUQXZ", "1413313701", 2.0, 1312070400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A5JLAU2ARJ0BO", "1413313701", 3.0, 1310169600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ACVDL5QRCOPE1", "1413313701", 4.0, 1308096000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3H7ADUP07D93H", "1413313701", 3.0, 1306368000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2XU6J41ZQOJ2V", "1413313701", 5.0, 1295481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3BNMHRW2R35LK", "1413313701", 5.0, 1295481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3FFKU2MTCOBM1", "1413313701", 5.0, 1293494400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A36WTQL2AW6NR5", "1413313701", 4.0, 1292457600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1TR1R2QKWRSRA", "1413313701", 4.0, 1292371200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A226VGZWOEBPGL", "1413313701", 5.0, 1292371200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A11SWG9T60IQH8", "1413313701", 5.0, 1290470400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ABOYCZON8UEGJ", "1413309674", 5.0, 1252886400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1EH2S92FHWZRP", "1413309674", 5.0, 1252454400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2HMF8ZR67BNZS", "1413309674", 3.0, 1248998400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3AYSYSLHU26U9", "1413309674", 5.0, 1247529600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1T2ZO4ARVSUGE", "1413313728", 2.0, 1294444800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A16RI68PS6T5CA", "1413313728", 4.0, 1293321600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1GWG5CWLKJ7ET", "1413313728", 5.0, 1293062400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1HOLE9R6WPT85", "1413313728", 4.0, 1327536000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ALQ4USPEQ9L5N", "1413313728", 5.0, 1321488000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1GQRGB8FGSLIZ", "1413313728", 5.0, 1318032000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ACVDL5QRCOPE1", "1413313728", 5.0, 1316822400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A26LQSC65AMTGK", "1413313728", 5.0, 1308182400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2SZLNSI5KOQJT", "1413313728", 3.0, 1299974400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A7JGEKN140F4S", "1413313728", 4.0, 1298937600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3LDLV1GWQJLEQ", "1413313728", 5.0, 1297900800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1D7VWS3DWS7X8", "1413313728", 5.0, 1295481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3LGT6UZL99IW1", "1413313728", 5.0, 1294876800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A23Y6DXVZTTXKJ", "1426296355", 5.0, 1353888000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3CAG7WLTAKPI", "1426296355", 5.0, 1341964800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MRPX3RM48T2I", "1426296355", 3.0, 1275868800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A32B6XWNR55SRL", "1426296355", 5.0, 1263772800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A38KK0SZYEH5UD", "1426296355", 5.0, 1261180800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A22RY8N8CNDF3A", "1426296355", 5.0, 1260489600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ARADXCOUVBS09", "1426296355", 5.0, 1259884800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A11REZES0TNBSD", "1426296355", 5.0, 1259712000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1X4EQRYDZ84BV", "1597750328", 1.0, 1207612800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3UPFPG415SBWB", "1597750328", 1.0, 1284336000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3F3B6HY9RJI04", "1600775411", 3.0, 1348444800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AD1ZOPB0BBEHB", "1600775411", 4.0, 1340841600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AHQRU3MRORIWQ", "1600775411", 4.0, 1332201600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1SCANWWQTEG9I", "1600775411", 3.0, 1329436800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WBEIH7Z37LN9", "1600775411", 4.0, 1313539200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2F2S1L61X1LA9", "1600775411", 4.0, 1302480000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A21OGQWFAKGC41", "1600775411", 4.0, 1299110400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1A21GIPMY89BZ", "1600775411", 1.0, 1296777600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2B3CIEV3SW6EG", "1600775411", 2.0, 1276646400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3RF46CL8GDIN8", "1600775411", 3.0, 1275264000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A8WAYVOKYBLO6", "1600775411", 3.0, 1274313600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1U7LS93I03MFW", "1600775411", 4.0, 1271894400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A268QM4AOCO9NI", "1600775411", 1.0, 1270857600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2YKWYC3WQJX5J", "1600775411", 3.0, 1270080000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A301B6L3TCD7WL", "1600775411", 3.0, 1266364800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WN1QF8GSVHYV", "1600775411", 4.0, 1266105600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3D5B2CBFNJB0K", "1600775411", 4.0, 1265932800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3OXHLG6DIBRW8", "1600775411", 3.0, 1265414400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1ZZR25X0CNOJX", "1600775411", 4.0, 1264896000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AYVM2DODURDLE", "1600775411", 4.0, 1264723200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3S3R88HA0HZG3", "1600775411", 4.0, 1259020800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2JCJJNY43QQIV", "1600775411", 2.0, 1258588800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3FGJDBSMCSG7G", "1615354336", 5.0, 1284940800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A225G2TFM76GYX", "1615354336", 4.0, 1284508800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A33XJPI7NIPDHB", "1615354336", 3.0, 1312848000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3K9K53Y7E1OTM", "1615354336", 5.0, 1301616000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2LXC5ZHHP0WXP", "1617160199", 5.0, 1299110400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A19TKRB4LR9ZX0", "1931020752", 5.0, 1250035200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3M6P5P0NLPTP3", "1931020752", 2.0, 1361577600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A225G2TFM76GYX", "1935341049", 1.0, 1326758400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1IJPJPYN1AKSZ", "1935341049", 1.0, 1314489600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2FQ5HDT4DWZNH", "1935341049", 2.0, 1304899200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WLDEORTNRY0D", "1935341049", 1.0, 1300924800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WMEOGVZKO8MI", "2749010993", 4.0, 1171756800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1E3OB6QMBKRYZ", "3937514775", 5.0, 1232236800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A20DZX38KRBIT8", "3937514775", 1.0, 1236211200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2F2F7N94SR1KQ", "3959828101", 1.0, 1475107200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3LJ2XUYKO6F2", "3959828101", 5.0, 1488585600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AYICV8N9QCSBE", "3959828101", 5.0, 1487635200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3M2QH93GOKJLW", "3959828276", 1.0, 1487548800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AS2GVS22GP162", "3959828241", 2.0, 1499904000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MH90R0ADMIK0", "3959828241", 1.0, 1487808000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3TPKBOJKCP6F3", "3959828241", 5.0, 1478736000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WCFDOCS73PNB", "395982825X", 2.0, 1485302400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37I5YKH71AVFD", "B00000K4CS", 1.0, 1071360000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1RUBF0FK78E5Y", "B00000K4KT", 5.0, 1275004800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AT2BYFEVLVITT", "B00000K4KT", 5.0, 958694400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MO9MSH7RFFC8", "B00001SHKN", 4.0, 1238198400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2L28CAIUAT503", "B00001SHKN", 5.0, 1198713600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A35KD1U1M387I0", "B00001XDWZ", 5.0, 1032220800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A15IZQLN9J5CCQ", "B00001XDWZ", 5.0, 963705600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A7EJERNB7IK3Z", "B00001XDWZ", 1.0, 1347667200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3QQO9GVE0GOFE", "B00001YVBG", 3.0, 944006400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2NYCHZ7MZ3OU3", "B00001XDW8", 5.0, 1391817600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30YE6NE9XFX9C", "B00001XDW8", 5.0, 1289088000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3U78OW4OO2Q8W", "B00001XDW8", 3.0, 1253836800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1NF93OYP9ZCT5", "B000021YVS", 5.0, 1039478400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WTCSBFHDKJMS", "B000021YVS", 5.0, 986342400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PEO80SRE0067", "B000021YW8", 4.0, 1309737600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2G0O4Y8QE10AE", "B000021Z1D", 5.0, 960249600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A18TLWHJG3GPZO", "B000021Z1O", 5.0, 1149984000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATD2TKJE84XRM", "B000021Z1O", 4.0, 976924800 );
#   1%|          | 196/21887 [00:00<23:37, 15.30it/s]
#
#   1%|          | 254/21887 [00:00<16:40, 21.61it/s]
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2AGUG8B7T7DP4", "B000021Z1O", 5.0, 1416441600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A21H4R2TIHTYXL", "B000021Z1O", 5.0, 1392681600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A2RMW9SQS60B", "B000023VV2", 5.0, 1082160000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30H2335OM7RD6", "B000023VV2", 5.0, 1053043200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATD2TKJE84XRM", "B000023VVY", 5.0, 968284800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A2RMW9SQS60B", "B000023VVY", 5.0, 1043452800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3MVMPFBN1RFFV", "B000023VVH", 5.0, 1105747200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28FRGJMMTWKKD", "B000023VU1", 5.0, 1052870400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IE7YPWUYZAXS", "B000023VU1", 4.0, 964569600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGVY193PRPLZC", "B000023VU1", 5.0, 950227200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1QSF4JURQA14I", "B000023VU1", 5.0, 1239148800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1U7LS93I03MFW", "B000023VU1", 5.0, 1096329600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B000023VU1", 5.0, 1069459200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30H2335OM7RD6", "B000028EHU", 4.0, 1022112000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B000028F4I", 2.0, 982281600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28FRGJMMTWKKD", "B000028EHV", 2.0, 1015977600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AUM3YMZ0YRJE0", "B000028EHV", 4.0, 1011916800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30H2335OM7RD6", "B000028EHV", 5.0, 1004227200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1DTOHMM2Y5KY0", "B000029714", 5.0, 947376000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A243HY69GIAHFI", "B0000296ZH", 3.0, 946944000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3H4TIVTTA5IBB", "B0000296ZH", 3.0, 943660800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATD2TKJE84XRM", "B0000296OP", 5.0, 977961600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3FE2GUBM8JZ3G", "B0000296YH", 2.0, 963446400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2DJDS2KLFR9YM", "B00002K10B", 4.0, 944524800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2SR8P74KODIB4", "B00002JV9C", 5.0, 1413417600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A5HLFUJ5WU2B", "B00002JV9C", 5.0, 1403308800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1Y7QU3BUUSI6R", "B00002JV9C", 5.0, 1349481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A247L282PID4PE", "B00002JV9C", 3.0, 1339891200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PNZV9C1YZVCP", "B00002JV62", 5.0, 966384000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1ZBYJ4ET9FZNC", "B00002JV62", 1.0, 1420934400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3O23O3490MM6L", "B00002JV62", 5.0, 1358899200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3MV1KKHX51FYT", "B00002JV62", 5.0, 1270080000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1LCS3WQEWUO6Y", "B00002JV62", 5.0, 1225411200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B00002S6E4", 5.0, 1068076800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AXJTNYD3UK1BP", "B00002S6E4", 5.0, 1050969600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28FRGJMMTWKKD", "B00002S6E4", 5.0, 1019433600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGVY193PRPLZC", "B00002S6E4", 5.0, 951264000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A38R6K4AGOC0Q3", "B00002S73L", 3.0, 984182400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3C1MJ6AYAJ1PP", "B00002S73L", 4.0, 958435200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2G0O4Y8QE10AE", "B00002S8OY", 5.0, 960249600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3C1MJ6AYAJ1PP", "B00002S9PT", 4.0, 958435200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1C9C1QOQB94RT", "B00002SFM4", 4.0, 1011744000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AJI21OXVSBXLK", "B00002SFM4", 5.0, 986774400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1IU7S4HCK1XK0", "B00002SFM4", 4.0, 986601600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3H1CE8T6GDVWV", "B00002SFM4", 3.0, 982108800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2SRVDDDOQ8QJL", "B00002SFM4", 4.0, 976492800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AQ6XS10RR7CE0", "B00002SFM4", 4.0, 975110400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3S87ZOPB3UM9N", "B00002SFM4", 5.0, 971913600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A281NPSIMI1C2R", "B00002SFM4", 5.0, 965692800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3C1MJ6AYAJ1PP", "B00002SFM4", 1.0, 958435200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZWTRKAX60DLB", "B00002SFM4", 2.0, 957744000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AJPH8OQSWKR7K", "B00002SFM4", 4.0, 955324800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A15L96IYUO6V", "B00002S9MI", 4.0, 958694400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1G1UA4XSWAZW9", "B00002SAM7", 1.0, 1169164800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AK94AGPA2L5GY", "B00002SA8D", 4.0, 964137600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A243HY69GIAHFI", "B00002SA8D", 4.0, 956016000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MPR99AJWXJX0", "B00002SA8D", 1.0, 1309132800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30J7WQV0ZNRXG", "B00002SA8D", 1.0, 1175990400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IE7YPWUYZAXS", "B00002S6GE", 5.0, 971395200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGVY193PRPLZC", "B00002S6GE", 5.0, 960940800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1DOWCPTD2S62F", "B00002S6GE", 5.0, 1406851200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A33WIN510NQ3GK", "B00002S6GE", 5.0, 1221177600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2PCZAO3O1O0SE", "B00002S6GE", 2.0, 1178409600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B00002S6GE", 5.0, 1068076800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AXJTNYD3UK1BP", "B00002S6GE", 5.0, 1050969600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1NF93OYP9ZCT5", "B00002SAHO", 5.0, 1039478400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3H4TIVTTA5IBB", "B000035Y9O", 4.0, 985392000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WTCSBFHDKJMS", "B00003IEGE", 5.0, 985564800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3TUWNDO2728F3", "B00003IRBU", 5.0, 1152662400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AI290A0Z9Y3XF", "B00003IRBU", 4.0, 1127865600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AYJF535SFBGXO", "B00003IRBU", 4.0, 1127520000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A8ZWV1PQWXK5", "B00003IRBU", 2.0, 1060041600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1P4RH7KMJ1SV2", "B00003IRBU", 4.0, 980985600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2JFOHC9W629IE", "B00003JAU9", 5.0, 1010275200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IFZ00ICAERE4", "B00003JAU9", 5.0, 1009929600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AQ6XS10RR7CE0", "B00003JAU9", 4.0, 998006400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3CWH6VKCTJAD", "B00003JAU9", 2.0, 996364800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A20ES0B827C52C", "B00003JAU9", 4.0, 989366400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1IU7S4HCK1XK0", "B00003JAU9", 4.0, 986860800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1KJ94X41TJLX0", "B00003JAU7", 1.0, 950745600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3PD6NG6XL336W", "B00003IRBV", 2.0, 1306281600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3ANETCTMAN1NP", "B00003IRBV", 4.0, 1284854400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AI290A0Z9Y3XF", "B00003IRBV", 5.0, 1127865600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AYJF535SFBGXO", "B00003IRBV", 5.0, 1127520000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A16UJ76AFPJGEX", "B00003JAU7", 5.0, 1158969600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A14JBDSWKPKTZA", "B00003JAU7", 5.0, 1121990400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3A8ZWV1PQWXK5", "B00003IRBV", 3.0, 1060041600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A26NSROS057DX9", "B00003IRBV", 5.0, 1059091200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2J5Y9MKKQTXGW", "B00003IRBV", 3.0, 1056585600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A5FS50VW0GWEE", "B00003JAU7", 5.0, 1110499200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AD0J5KK4WQXNS", "B00003JAU7", 5.0, 1071705600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AG42CYU5P8NVQ", "B00003JAU7", 5.0, 1058140800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A16SG04X5KYYKW", "B00003JAU7", 5.0, 1051315200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3EQ61ES6HQ090", "B00003JAU7", 5.0, 1023840000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AWIF8AR75LL9L", "B00003IRBV", 5.0, 1000252800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1P4RH7KMJ1SV2", "B00003IRBV", 5.0, 980294400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1C9C1QOQB94RT", "B00003JAU7", 4.0, 1012953600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3JRAKUG0TB81C", "B00003JAU7", 4.0, 990748800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AE95Z3K6GVIC3", "B00003JAU7", 1.0, 977443200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2ZU50LRKINN8B", "B00003JAU7", 5.0, 974937600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1C8V13RD60LTR", "B00003JAU7", 5.0, 967507200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ARXU3FESTWMJJ", "B00003JAU7", 4.0, 966988800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3C1MJ6AYAJ1PP", "B00003JAU7", 4.0, 952387200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1M5P9TYPKHYLF", "B00003ZANM", 4.0, 952128000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AB10W5FUXWAJ", "B00003ZANM", 1.0, 969926400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IE7YPWUYZAXS", "B00004NHKM", 5.0, 964569600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A33WIN510NQ3GK", "B00004NHKM", 4.0, 1221177600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1QSF4JURQA14I", "B00004NHKM", 5.0, 1193702400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1U7LS93I03MFW", "B00004NHKM", 5.0, 1096329600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B00004NHKM", 5.0, 1069459200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28FRGJMMTWKKD", "B00004NHKM", 5.0, 1052870400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1U7LS93I03MFW", "B00004NHKU", 5.0, 1096329600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30H2335OM7RD6", "B00004NHKU", 4.0, 1230422400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2AV7Q95QGPTO0", "B00004R8KU", 1.0, 996364800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1IK790BI344RH", "B00004R8KU", 3.0, 966556800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2NYK9KWFMJV4Y", "B00004S4XY", 5.0, 1019433600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A13586UCKKITJZ", "B00004S4XY", 5.0, 990921600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AQ6XS10RR7CE0", "B00004SZK1", 4.0, 976233600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A6V9YCQJSXKH7", "B00004TEY4", 5.0, 1131580800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1A51F2UV48IZT", "B00004THQH", 2.0, 1014940800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3V6Z4RCDGRC44", "B00004TJE6", 4.0, 971049600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1NF93OYP9ZCT5", "B00004TJ01", 3.0, 1039478400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2C27IQUH9N1Z", "B00004TJCM", 5.0, 1068076800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2OIXM5GEIAWD1", "B00004TJCM", 5.0, 1050278400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2A2POT5RGXTEQ", "B00004TJCM", 4.0, 1257206400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PEO80SRE0067", "B00004TLO0", 4.0, 1265932800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATD2TKJE84XRM", "B00004TTUB", 5.0, 976147200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2G0O4Y8QE10AE", "B00004TYCR", 5.0, 961977600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ANEDXRFDZDL18", "B00004TYCR", 3.0, 1104883200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3RF46CL8GDIN8", "B00004TYCR", 4.0, 1096416000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PPD5TOR6VVYV", "B00004TYCR", 5.0, 1067385600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3KIEI1BC9CENU", "B00004TYC4", 1.0, 1166313600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3B20R4ZAH0Y2Y", "B00004U5R7", 5.0, 1086048000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A15S4XW3CRISZ5", "B00004U9LR", 2.0, 1015372800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28ANPKNFQXTP3", "B00004U9LR", 3.0, 1007424000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3LMPD1ZQTWOC4", "B00004UB5G", 5.0, 1305936000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AOWU1SSONBZZX", "B00004UB5G", 5.0, 1019779200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A28FRGJMMTWKKD", "B00004UB5G", 4.0, 1015977600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2M10P5VJUG4VD", "B00004UCUS", 5.0, 1370822400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A29THQFOAB9U4U", "B00004UF32", 5.0, 1131840000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AUM3YMZ0YRJE0", "B00004UF32", 4.0, 1111276800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2UDJ3K41GUL1E", "B00004UF32", 5.0, 1436918400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30YE6NE9XFX9C", "B00004UF31", 5.0, 1289088000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2EGK0YRDF4ZZB", "B00004UFGD", 4.0, 976320000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1G1UA4XSWAZW9", "B00004VXAA", 5.0, 1169942400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AXJTNYD3UK1BP", "B00004VXAI", 4.0, 1081468800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3GQKB1KF0CRPE", "B00004W3GS", 4.0, 1030147200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IFZ00ICAERE4", "B00004W4AM", 5.0, 970099200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3CWH6VKCTJAD", "B00004W4AM", 5.0, 969321600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3TQEF7QWHABGE", "B00004W4AM", 1.0, 983318400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1P7MAO0LW6HCZ", "B00004W4AM", 1.0, 983145600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A176Y7DNY6H2DN", "B00004W4AM", 1.0, 972950400 );
#   2%|▏         | 348/21887 [00:00<11:48, 30.38it/s]
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AR2DE47VCY1C8", "B00004W62P", 4.0, 989971200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2IE7YPWUYZAXS", "B00004W62P", 5.0, 980294400 );
#   2%|▏         | 401/21887 [00:01<09:46, 36.62it/s]
#
#   2%|▏         | 494/21887 [00:01<06:55, 51.44it/s]
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AB10W5FUXWAJ", "B00004W62P", 4.0, 971827200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AT2BYFEVLVITT", "B00004W62P", 3.0, 966470400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AT2BYFEVLVITT", "B00004W62O", 3.0, 966470400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1LCS3WQEWUO6Y", "B00004W62O", 5.0, 1225411200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A20DZX38KRBIT8", "B00004W62O", 1.0, 1210291200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A16UJ76AFPJGEX", "B00004W62O", 1.0, 1155427200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AE95Z3K6GVIC3", "B00004W62O", 1.0, 1001635200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1R9QOPV6HVEKF", "B00004W62O", 1.0, 1001030400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AV3DZX3NU7NWU", "B00004W62O", 1.0, 999993600 );
# ...
#         VALUES  ("A2UXDOS0WFZCWQ", "B01586EXIK", 2.0, 1470268800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A10NC6ZVVMBHNH", "B015C9KOHM", 5.0, 1532390400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2TB314DVO8VJ0", "B015C9KOHM", 5.0, 1480636800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A32WT2XDGLGPS2", "B015C9KO9K", 5.0, 1468627200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A9EL8GNJCW9S8", "B015C9KLNE", 5.0, 1475971200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A209TO7BY4Q0QL", "B015E1C764", 1.0, 1472083200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AY7Z0W9EKBCBB", "B015IHWAZW", 5.0, 1515801600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AOOWG6KYD32UJ", "B015IHWAZW", 5.0, 1512086400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A377FI7BV0X32K", "B015MI2AYI", 5.0, 1517356800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1NTUHB72MS4WS", "B015MI2AYI", 1.0, 1486944000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3DD7H4DNMV5G2", "B015NXUK30", 5.0, 1500163200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B015NXUOP4", 4.0, 1463356800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B015NXUK2G", 4.0, 1464393600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AL1R9APK6DD0I", "B015NXUK2G", 5.0, 1461888000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B015NZ8QX4", 3.0, 1463097600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3OPKL03NFOSZJ", "B015NZ8QX4", 5.0, 1457481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1J44U25X547CG", "B015ONJ9KO", 5.0, 1459296000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1RHJX6OA0O9KQ", "B015OQD2AY", 4.0, 1470268800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A34AN3NF8P7PJ", "B015OY6WKS", 5.0, 1530144000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A33WMYNNZ32I5I", "B015PIIGQ6", 3.0, 1487030400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A377FI7BV0X32K", "B015SWVD3M", 5.0, 1521590400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2DKUVUY6M48YF", "B015SWVD3M", 2.0, 1512000000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1G8RES4IB05KH", "B015UAMV6A", 1.0, 1530144000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A22D1JM7VRP2D", "B015VXUNYS", 5.0, 1452211200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30W19MJFRJE3J", "B015WQG49M", 1.0, 1465948800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AMFRDOHR04TVE", "B015WQG1MC", 4.0, 1450396800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30W19MJFRJE3J", "B015WQFTMA", 1.0, 1465948800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AKZ27IK4U3WDQ", "B015XDQD4K", 5.0, 1513209600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A17K8EJBW22UGS", "B015XDQD4K", 5.0, 1464825600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AW42V7SDGU8LR", "B015XDQE7G", 2.0, 1494028800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AGTO21BHY08LF", "B015XL5BRW", 1.0, 1476748800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B015XL978G", 4.0, 1460505600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2158Q3GDLSC83", "B015XL978G", 4.0, 1454544000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ATCJDCFBCYLSU", "B015XLKOA6", 5.0, 1467763200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2ONJRZVX2MLVE", "B01617VO2S", 5.0, 1522972800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A50JAPK902TOL", "B01617VO2S", 5.0, 1500940800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1QWPLIPX2XP97", "B01617VTFK", 5.0, 1468627200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A11Q2OISO3PUGJ", "B01633BSCG", 5.0, 1486598400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A264KMMQIISV0A", "B01637REAM", 5.0, 1523318400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3C1UZJUUUB3MI", "B01637RK6U", 5.0, 1507852800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A5R1VT4MTNZKT", "B01637RK6U", 5.0, 1476921600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3SS2AQD9IPMKN", "B01637REWA", 3.0, 1475884800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3ISA8LBB5P34E", "B01637RGG4", 3.0, 1500681600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2ONJRZVX2MLVE", "B01637RHBI", 5.0, 1522972800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3RNXWG0J64Z9Z", "B0169RGE7U", 5.0, 1529452800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZ1BVH7L08KOM", "B016HSBQ6K", 5.0, 1480982400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3NH1UC1RSQ4LZ", "B016HSBQ6K", 5.0, 1467849600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2M3KEMN3U4IBO", "B016K0WV0U", 1.0, 1453161600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2DD75DKCSINRR", "B016K0WV0U", 1.0, 1451606400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2F39A7D2BU66B", "B016VA2IT8", 1.0, 1494288000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37TGQDQ4MMPTM", "B016WE2VXQ", 5.0, 1456963200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37P0E2D6WKEJR", "B01723PCUA", 5.0, 1485561600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1R5NYTW214KG4", "B01723PG10", 5.0, 1523750400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3L89YSXTNEFMR", "B01723PG10", 5.0, 1504396800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3QT7HVVGKG6MK", "B01787N7FW", 1.0, 1474070400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2Y3WWPUKIJ59I", "B017JPEDWO", 1.0, 1478304000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2JROLOG9LZT1Y", "B017JPEDWO", 5.0, 1472169600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1ABOAZ99VXIJO", "B017JPEDWO", 4.0, 1460419200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1G9JCB54XMLAW", "B017MWP6G6", 3.0, 1516406400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3IOW3B21MCANN", "B017NWX5VS", 1.0, 1488153600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1NKB1G7WTTWK9", "B017QOSCBQ", 5.0, 1472428800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AM065SAAM3YO1", "B017QOSCBQ", 3.0, 1463616000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37COS0OKINK6G", "B0188PUVO8", 2.0, 1504656000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37COS0OKINK6G", "B0188QBU0Q", 2.0, 1503619200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3TN3R1BV4VBZT", "B018PRO6MC", 5.0, 1477353600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A4HJUEM7EU8HV", "B018RUWG06", 2.0, 1512432000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2CSLP2OHHENS0", "B019GBF2PQ", 5.0, 1481068800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1A4BSCU1PX7EX", "B019MUXHWQ", 1.0, 1499990400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ASPQ2XL8LJ7HC", "B019QWTLAC", 4.0, 1476316800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B019WZ0XB4", 4.0, 1471305600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A27JQB7JMGFLKR", "B01A5LUPF8", 1.0, 1484956800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3UES3NOHCZO4B", "B01A8844XM", 2.0, 1475020800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1THNW9Y672UWG", "B01AC3ZAHW", 4.0, 1522627200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1X9CUYJPF22WM", "B01AC3ZAHW", 1.0, 1522281600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1ZOIGQHW7FPT2", "B01AC3ZAHW", 1.0, 1511481600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AV69BQQR8VCQA", "B01AC3ZA7C", 4.0, 1488499200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A377FI7BV0X32K", "B01AFXP5K6", 5.0, 1517356800 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MOLMEBRO23PR", "B01AFXP5K6", 5.0, 1509753600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PZNGHSDLY3EX", "B01AFXP5K6", 1.0, 1481760000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A204J8NE673XES", "B01BL7ELNC", 1.0, 1481587200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2ESCB4LEZ9JHV", "B01BUGW028", 4.0, 1511395200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A30W19MJFRJE3J", "B01BWMDTB6", 1.0, 1529366400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("ABK6QL1MM7LYQ", "B01BWMDTB6", 1.0, 1523750400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A37IBQNKHOX2VA", "B01BWMDTB6", 2.0, 1489968000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3KT4CYVKQOWBS", "B01BXDS8KG", 5.0, 1457568000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3VL4RXCWNSR3H", "B01C1J8U04", 4.0, 1484697600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A17F4K4S2TVSQH", "B01C3KPFA4", 5.0, 1483401600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WU20MITX7F6N", "B01C3KPFA4", 5.0, 1471737600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1PRM32W8RPBL0", "B01C51HXM4", 5.0, 1474502400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AIN37ALFNB3NO", "B01C6SEW5W", 4.0, 1480896000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AW7ZOPB601PRX", "B01C7QAWR0", 1.0, 1500249600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A11Q2OISO3PUGJ", "B01CHBQVPC", 5.0, 1486598400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AF24RCNXHP7Y9", "B01CUQ17SU", 1.0, 1515715200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AB094YABX21WQ", "B01DEEYSZG", 4.0, 1525824000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3PGN4ZXMQRSYH", "B01DEEGRY6", 5.0, 1519603200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AF502FLL5WFZ3", "B01DEG0SGC", 1.0, 1527897600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3PGN4ZXMQRSYH", "B01DEG0SGC", 5.0, 1519862400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1TYYT15KT9TDQ", "B01DF59LV0", 2.0, 1460937600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A14VK218ZCKYAL", "B01DF4RUYQ", 5.0, 1507334400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZ8NQPFR743F0", "B01E5L50X6", 5.0, 1470787200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AVIEW8BOT4ZA", "B01E5NKAOS", 5.0, 1533168000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2FUGL44X83UV4", "B01E5NKAOS", 2.0, 1515801600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3W4D8XOGLWUN5", "B01E5NKAOS", 4.0, 1472083200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2DKUVUY6M48YF", "B01E6C5D1S", 1.0, 1512000000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1MOLMEBRO23PR", "B01E6C5D1S", 4.0, 1479686400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1RHJX6OA0O9KQ", "B01E6C5D1S", 4.0, 1479081600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A20QR509GXKL2A", "B01E6C5D1S", 4.0, 1475280000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A34ZISTZ0YT4CD", "B01EBIQ38E", 4.0, 1494806400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1WU20MITX7F6N", "B01EH08XMA", 5.0, 1493856000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A22UEGDX65VTZZ", "B01ETNVTSK", 4.0, 1521417600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3IB1W0SVED0Z3", "B01EX7HHPG", 5.0, 1476057600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A8UNKMA6FSVLF", "B01EXJXR8U", 1.0, 1476576000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A35SZBPM3WCB4", "B01FFVDY9M", 4.0, 1472515200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3EK2KTYHJCPB9", "B01FFVDY9M", 4.0, 1469491200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A5U5T6EWH90O0", "B01FFVDY9M", 5.0, 1468713600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A1E50L7PCVXLN4", "B01FFVDY9M", 4.0, 1468627200 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A3KIG6IKEDM0JT", "B01GF2LA6O", 5.0, 1477440000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AVU1ILDDYW301", "B01HAP3NUG", 3.0, 1497657600 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2LW5AL0KQ9P1M", "B01HAP3NUG", 4.0, 1485216000 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("AZ515FFZ7I2P7", "B01HAP47PQ", 3.0, 1528934400 );
# INSERT INTO valoracion(idSocio, idProducto, rating, unix_time)
#         VALUES  ("A2WPL6Y08K6ZQH", "B01HAP47PQ", 4.0, 1523836800 );

# %%
# conn.rollback()
conn.commit()

# %%
# Out:
# 0
